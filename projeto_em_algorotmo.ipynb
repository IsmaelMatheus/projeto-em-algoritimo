# %% [markdown]
# <a href="https://colab.research.google.com/github/IsmaelMatheus/projeto-em-algoritimo/blob/main/projeto_em_algorotmo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time # Biblioteca para simular o tempo passando

# %%
print("---INICIANDO O ALGORITMO DO BOLO---")
# Out:
# ---INICIANDO O ALGORITMO DO BOLO---

# %%
# 1. Variáveis: Separando os ingredientes e ferramentas
temperatura_forno  = 0
forma_unta = True
tigela = [] # Uma lista vazia para colacar os ingredientes
massa_homogenea = False
tempo_de_forno = 40
palito_limpo = False
